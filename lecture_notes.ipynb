# %%
import numpy as np
import pandas as pd

# %%
student_dict = {'Name': ['Joe', 'Nat', 'Harry'], 'Age': [20, 21, 19], 'Marks': [85.10, 77.80, 91.54]}

student_df = pd.DataFrame(student_dict)

student_df.head()

# %%
student_df.describe()

# %%
list_Index = student_df.columns
print('Columns Names', list_Index)

# %%
df_cars = pd.read_json('data/cars.json')

# %%
df_cars['Car']

# %%
df_cars[['Car', 'MPG', 'quantity']]

# %%
df_cars[df_cars.columns[[0, 1, 2]]]

# %%
# Sample DataFrame
data = {'Category': ['Electronics', 'Clothing', 'Electronics', 'Books', 'Books', 'Clothing']}

cat_df = pd.DataFrame(data)

cat_df.value_counts()

# %%
# Create the dataframe
sales_data={"Devices":['Laptop','iPhone','LED','LCD','Smart-Phone','Washing-Machine'],
           'Brand':['Lenovo','Apple','Samsung','Samsung','Samsung','Whirpool'],
           'Sales':[1000,2000,4000,2000,1000,4000],
           'Profit':[500,1000,1000,1500,1000,1500],
           'Pices left':[5000,4000,4000,5000,5000,1000]}
sales_df = pd.DataFrame(sales_data)

# %%
d = {'x': [1, 2, 3], 'y': [2, 4, 8], 'z': 100}
df = pd.DataFrame(d)
print(f'dictionary: d')
print("\nDataFrame")
print(df)

# %%
# Value counts of categorical data
cars_df['city'].value_counts()

# %%
cars_df['city'].unique()

# %%
cars_df.info()

# %%
cars_df.count()

# %%
cars_df.head(2)

# %%
cars_df.tail(2)

# %%
# .at method to grab specific values from dataset
cars_df.at[159, "MPG"]

# %%
# .at method to grab specific values from dataset using the index number
cars_df.iat[159, 1]

# %%
student_dict = {'Name': ['Joe', 'Nat', 'Harry'], 'Age': [20, 21, 19], 'Marks': [85.10, 77.80, 91.54]}
students_df = pd.DataFrame(student_dict)
student_df.head()

# %%
student_df.describe()

# %%
list_Index = student_df.columns
print('Columns Names', List_Index)

# %%
label = student_df.columns[0]
print(label)

# %%
# Getting the column names as a list for looping

labels_as_list = student_df.columns.to_list()
print(labels_as_list)

# %% [markdown]
# EDA w/ CSV

# %%
e_df = pd.read_csv('data/employee.csv')

# %%
e_df.head(10)

# %%
e_df.tail(2)

# %%
e_df.info()

# %%
rows, cols = e_df.shape
print('Rows:', rows)
print('Columns:', cols)

# %%
e_df2 = pd.read-csv('data/employee.csv', skiprows=5, header= None)
e_df2

# %%
# Getonly specific columns from CSV
e_df3 = pd.read_csv('data/employee.csv', usecols=['Name', 'Salary']) # based on labels
e_df3 = pd.read_csv('data/employee.csv', usecols=['0, 3'])   #based on index numbers
e_df3

# %%
e_df2 = pd.read-csv('data/employee.csv', skiprows=5, header= None)
e_df2

# %% [markdown]
# Selecting Columns

# %%
df_cars = pd.read_json('data/cars.json')
df_cars.head()

# %%
df_cars['car']

# %%
# Accessing a series with a index number

df_cars[df_cars.columns[0]]

# %% [markdown]
# Fequency Analysis - Value counts

# %%
# Sample DataFrame

data = {'Category': ['Electronics', 'Clothing', 'Electronics', 'Books', 'Books', 'Clothing']}

cat_df = pd.DataFrame(data)

# .value _counts
cat_df.value_counts()

# %%
# create the dataframe
sales_data={"Devices":['Laptop', 'iphone', 'LED', 'LCD', 'Smart-Phone', 'washing-Machine'], 
            'Brand':['Lenovo', 'Apple', 'Samsung', 'Samsung', 'Samsung', 'Whirlpool'],
            'Sales':[1000,2000,4000,2000,1000,4000],
            'Profit':[500,1000,1000,1500,1000,1500],
            'Prices left':[5000,4000,4000,5000,5000,1000]}

# Get frequency count for brands
Frequency = sales_df['Brand'].value_counts()
# print(Frequency)

frequent _product = Freqency[Frequency > 1].index[0]

print(Frequency)
print(f'This item appears more than once: {frequent_product}')

# %%
data = {'Score': [85, 92, 88, 75, None, 90, None, 85]}
scores_df = pd.DataFrame(data)

# %%
score_counts = scores_df.value_counts(dropna=False) # drapna, tells function to either include or NOT include NaN, Null, NA values
print('Score:', score_counts)

# %% [markdown]
# Rename a column in pandas
